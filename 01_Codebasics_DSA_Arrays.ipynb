# %% [markdown]
# <a href="https://colab.research.google.com/github/zizanayub/Data-Structure-and-Algorithms/blob/main/01_Codebasics_DSA_Arrays.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Exercise
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Solution to 01

# %%
monthly_expenses = [2230,2350,2600,2130,2190]
print(monthly_expenses[1] - monthly_expenses[0])
# Out:
# 120

# %% [markdown]
# ## Solution to 02

# %%
print(monthly_expenses[0]+monthly_expenses[1]+monthly_expenses[2])
# Out:
# 7180

# %% [markdown]
# ## Solution to 03

# %%
for i in monthly_expenses:
  if i == 2000:
    print(monthly_expenses[i])

# %% [markdown]
# ##Solution to 04

# %%
monthly_expenses.append(1980)
monthly_expenses
# Out:
# [2230, 2350, 2600, 2130, 2190, 1980]

# %% [markdown]
# ##Solution to 05

# %%
monthly_expenses[3] = monthly_expenses[3]-200
monthly_expenses
# Out:
# [2230, 2350, 2600, 1930, 2190, 1980]
